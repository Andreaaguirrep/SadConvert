# %%
from sad import *

input_file = "superKEKB/LER/sler_1801_80_1_cw80_sx1.sad"
print(f"Reading the input file: {input_file}")

sad_object = read_sad(input_file)

print(f"read object {sad_object}")
# Out:
# Reading the input file: superKEKB/LER/sler_1801_80_1_cw80_sx1.sad
# read: !IRData:                        irdata.class.SKEKB20171121A.sad ...
# >!IRData:<
# >!<
# >!<
# >!<
# >!<
# >!<
# >!<
# >!<
# >;<
# >OFF<
# >;<
# >DRIFT<
# found keyword : DRIFT
# >LBLC1LP1=(L<
# >LBLC1LP2=(L<
# >LLC1LB<
# >LLC2LA<
# >LXBLC2LP=(L<
# >LNBX2<
# >LXL580<
# >L2592<
# >LLB1L<
# >LLB2LB<
# >LLX1L1<
# >LQLX2LP<
# >LBLA1LP<
# >LXBLA2LP=(L<
# >LLA7L<
# >LLA9LA<
# >LLA10L<
# >LXB2P<
# >LZHQD1P1=(L<
# >LZHQD3P2=(L<
# >LZVQEAP<
# >L6P<
# >LZVQF4P3=(L<
# >LZHQD3P4=(L<
# >LZVQF2P5=(L<
# >LT0LP<
# >LTBLHP<
# >LT3LP<
# >LT4LHP<
# >LZHQT1TNP2=(L<
# >LZVQF4P6=(L<
# >LZHQD1P5=(L<
# >LZVQF4P9=(L<
# >LZHQD3P10=(L<
# >L4NP<
# >L3WWPN<
# >LZVQW8NRP=(L<
# >LZVQW6NRP=(L<
# >LBP1LN<
# >LWIGNR1<
# >LXW0N<
# >LXW4LN<
# >LZVQFWNP1=(L<
# >LZVQFWNP3=(L<
# >LZVQFWNP5=(L<
# >LZVQW4NLP=(L<
# >LBP1NP<
# >LW7NP2<
# >LZVQF6P7=(L<
# >LZHQD1P7=(L<
# >LZVQF6P8=(L<
# >LZHQD1P8=(L<
# >LZVQF6P9=(L<
# >LZHQD1P9=(L<
# >LZHQT3NFP1=(L<
# ...

# %%
# testing regexpr

cmd1 = "BEND   FHBBKP  =(ANGLE =0 )"
cmd2 = "BC1LP   =(L =.281105   ANGLE =-.0006948955567122189  E1 =1     ROTATE =-90 DEG     F1 =.177093 )"

import re

m = re.search(r"(\w+) =(\w+)",cmd1)
print(m.group())
print(m.groups())
# Out:
# ANGLE =0
# ('ANGLE', '0')

# %%
entries = re.split("\n+", open( "superKEKB/LER/sler_1801_80_1_cw80_sx1.sad").read())

# %%
cmd = entries[15]
# Out:
# '        LLC2LA  =(L =3.8393042429540003 )  LLC2LB  =(L =.6309099999999999 )   LXL12653=(L =.12653 )       LXL56467=(L =.56467 )'
